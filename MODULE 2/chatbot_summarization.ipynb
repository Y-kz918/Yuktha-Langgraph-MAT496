# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/chatbot-summarization.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239436-lesson-5-chatbot-w-summarizing-messages-and-memory)

# %% [markdown]
# # Chatbot with message summarization
#
# ## Review
#
# We've covered how to customize graph state schema and reducer.
#
# We've also shown a number of ways to trim or filter messages in graph state.
#
# ## Goals
#
# Now, let's take it one step further!
#
# Rather than just trimming or filtering messages, we'll show how to use LLMs to produce a running summary of the conversation.
#
# This allows us to retain a compressed representation of the full conversation, rather than just removing it with trimming or filtering.
#
# We'll incorporate this summarization into a simple Chatbot.
#
# And we'll equip that Chatbot with memory, supporting long-running conversations without incurring high token cost / latency.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_groq

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("GROQ_API_KEY")
# Out:
# GROQ_API_KEY: ··········

# %% [markdown]
# We'll use [LangSmith](https://docs.smith.langchain.com/) for [tracing](https://docs.smith.langchain.com/concepts/tracing).

# %%
_set_env("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"
# Out:
# LANGSMITH_API_KEY: ··········

# %%
from langchain_groq import ChatGroq
model = llm = ChatGroq(model="llama-3.3-70b-versatile",
                      api_key = os.environ.get("GROQ_API_KEY"),
                      temperature = 0
)

# %% [markdown]
# We'll use `MessagesState`, as before.
#
# In addition to the built-in `messages` key, we'll now include a custom key (`summary`).

# %%
from langgraph.graph import MessagesState
class State(MessagesState):
    summary: str

# %% [markdown]
# We'll define a node to call our LLM that incorporates a summary, if it exists, into the prompt.

# %%
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage

# Define the logic to call the model
def call_model(state: State):

    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:

        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]

    else:
        messages = state["messages"]

    response = model.invoke(messages)
    return {"messages": response}

# %% [markdown]
# We'll define a node to produce a summary.
#
# Note, here we'll use `RemoveMessage` to filter our state after we've produced the summary.

# %%
def summarize_conversation(state: State):

    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt
    if summary:

        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )

    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)

    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# %% [markdown]
# We'll add a conditional edge to determine whether to produce a summary based on the conversation length.

# %%
from langgraph.graph import END
from typing_extensions import Literal
# Determine whether to end or summarize the conversation
def should_continue(state: State) -> Literal ["summarize_conversation",END]:

    """Return the next node to execute."""

    messages = state["messages"]

    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"

    # Otherwise we can just end
    return END

# %% [markdown]
# ## Adding memory
#
# Recall that [state is transient](https://github.com/langchain-ai/langgraph/discussions/352#discussioncomment-9291220) to a single graph execution.
#
# This limits our ability to have multi-turn conversations with interruptions.
#
# As introduced at the end of Module 1, we can use [persistence](https://langchain-ai.github.io/langgraph/how-tos/persistence/) to address this!
#
# LangGraph can use a checkpointer to automatically save the graph state after each step.
#
# This built-in persistence layer gives us memory, allowing LangGraph to pick up from the last state update.
#
# As we previously showed, one of the easiest to work with is `MemorySaver`, an in-memory key-value store for Graph state.
#
# All we need to do is compile the graph with a checkpointer, and our graph has memory!

# %%
from IPython.display import Image, display
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Threads
#
# The checkpointer saves the state at each step as a checkpoint.
#
# These saved checkpoints can be grouped into a `thread` of conversation.
#
# Think about Slack as an analog: different channels carry different conversations.
#
# Threads are like Slack channels, capturing grouped collections of state (e.g., conversation).
#
# Below, we use `configurable` to set a thread ID.
#
# ![state.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbadf3b379c2ee621adfd1_chatbot-summarization1.png)

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
output = graph.invoke({"messages": [input_message]}, config)
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="what's my name?")
output = graph.invoke({"messages": [input_message]}, config)
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="i like the 49ers!")
output = graph.invoke({"messages": [input_message]}, config)
for m in output['messages'][-1:]:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hey Lance! 👋 Great to meet you. How can I help you today?
# ================================== Ai Message ==================================
#
# Your name is Lance. How can I assist you today?
# ================================== Ai Message ==================================
#
# That’s awesome! The 49ers have a rich history and some exciting talent on the roster.
#
# - **Current stars:** Brock Purdy, Deebo Samuel, Nick Bosa, and the ever‑reliable kicker Robbie Gould.
# - **All‑time legends:** Joe Montana, Jerry Rice, Ronnie Lott, and Steve Young.
#
# Do you have a favorite player, a memorable game, or a particular season that you love most? Let’s chat about the gold rush!

# %% [markdown]
# Now, we don't yet have a summary of the state because we still have < = 6 messages.
#
# This was set in `should_continue`.
#
# ```
#     # If there are more than six messages, then we summarize the conversation
#     if len(messages) > 6:
#         return "summarize_conversation"
# ```
#
# We can pick up the conversation because we have the thread.

# %%
graph.get_state(config).values.get("summary","")
# Out:
# ''

# %% [markdown]
# The `config` with thread ID allows us to proceed from the previously logged state!

# %%
input_message = HumanMessage(content="i like Nick Bosa, isn't he the highest paid defensive player?")
output = graph.invoke({"messages": [input_message]}, config)
for m in output['messages'][-1:]:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# You’re right—Nick Bosa is definitely up there among the highest‑paid defenders in the league, and for a good chunk of the 2024‑2025 seasons he actually **holds the top spot**.
#
# ### Why Bosa’s contract is so big
# | Year | Contract Details | Avg. Annual Value (AAV) |
# |------|------------------|------------------------|
# | **2022** (5‑year extension) | $170 million total, $115 million guaranteed | **$34 million per year** |
# | **2024‑2025 seasons** | Still under that extension (year 3 & 4) | $34 million AAV |
#
# - The $34 million AAV makes him the **most‑expensive defensive player on a per‑year basis** as of the 2024‑2025 NFL season.
# - The deal also includes a $30 million roster bonus in 2025 and a $10 million workout bonus in 2024, which push his cash earnings even higher in those years.
#
# ### How he stacks up against other elite defenders (2024‑2025)
#
# | Player | Position | Contract (AAV) | Current Status |
# |--------|----------|----------------|----------------|
# | **Nick Bosa** | DE (49ers) | **$34 M** | Under 5‑yr, $170 M extension (years 3‑5) |
# | **Aaron Donald** | DT (LA Rams) | $30 M (2023‑2024) – retired after 2024 season | Retired, but his last contract was $30 M AAV |
# | **T.J. Watt** | LB (Pittsburgh) | $28 M (2024‑2028) | 5‑yr, $140 M extension signed 2023 |
# | **Myles Garrett** | DE (Cleveland) | $27 M (2024‑2028) | 5‑yr, $135 M extension signed 2023 |
# | **Micah Parsons** | LB (Dallas) | $27 M (2024‑2028) | 5‑yr, $135 M extension signed 2023 |
# | **Jalen Ramsey** | CB (Miami) | $26 M (2024‑2028) | 5‑yr, $130 M extension signed 2023 |
# | **Josh Allen** | EDGE (Jacksonville) | $25 M (2024‑2028) | 5‑yr, $125 M extension signed 2023 |
#
# > **Bottom line:** Bosa’s $34 M AAV is the highest for any defensive player **right now**. The next‑closest contracts sit in the $27‑$28 M range.
#
# ### Why the 49ers were willing to pay that much
# 1. **Impact on the pass rush** – Bosa’s sack totals (12.5 sacks in 2023, 10.5 in 2022) and his ability to collapse the pocket make him a game‑changing weapon.
# 2. **Age & health** – He’s still in his mid‑20s and, despite a few injury hiccups early in his career, has shown durability since 2022.
# 3. **Market dynamics** – The NFL’s salary‑cap inflation (projected to be around $224 M in 2025) has pushed top defensive talent into the $30‑$35 M AAV range, and the 49ers wanted to lock Bosa in before the market spiked even higher.
#
# ### Quick trivia for a fellow 49ers fan
# - **Bosa’s first career sack** came against the **Los Angeles Rams** in Week 2 of his rookie season (2022).
# - He **tied the franchise record** for most sacks in a single season by a rookie with **9.5** (the record belongs to **Patrick Willis**, who had 9.5 in 2007).
#
# ---
#
# **Anything else you want to dive into?**
# - More details on Bosa’s on‑field performance metrics?
# - How the 49ers’ defensive scheme maximizes his skill set?
# - A look at the upcoming free‑agency landscape for defensive stars?
#
# Just let me know! 🚀🏈

# %%
graph.get_state(config).values.get("summary","")
# Out:
# '**Conversation Summary**\n\n| Turn | Speaker | Key Points |\n|------|---------|------------|\n| 1 | User (Lance) | Introduced himself. |\n| 2 | Assistant | Acknowledged Lance and asked how to help. |\n| 3 | User | Mentioned he likes the 49ers. |\n| 4 | Assistant | Responded enthusiastically, listed 49ers stars, legends, and asked about favorite player/season. |\n| 5 | User | Said he likes Nick\u202fBosa and asked if Bosa is the highest‑paid defensive player. |\n| 6 | Assistant | Confirmed Bosa holds the top spot for defensive players (2024‑2025) with a $34\u202fM average annual value (AAV) from his 5‑year, $170\u202fM extension. Provided a table comparing Bosa’s contract to other elite defenders, explained why the 49ers paid that amount, and added a few 49ers‑related trivia bits. |\n| 7 | User | Requested a summary of the conversation. |\n| 8 | Assistant | Delivered this concise summary. |'

# %% [markdown]
# ## LangSmith
#
# Let's review the trace!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### SUMMARY:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MY EXAMPLES:

# %% [markdown]
# We'll define the `State` with `messages` and `summary` keys.

# %%
from langgraph.graph import MessagesState

class State(MessagesState):
    summary: str

# %% [markdown]
# This node will include the summary in the prompt if it exists.

# %%
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage

def call_model(state: State):
    summary = state.get("summary", "")
    if summary:
        system_message = f"Summary of conversation earlier: {summary}"
        messages = [SystemMessage(content=system_message)] + state["messages"]
    else:
        messages = state["messages"]

    response = model.invoke(messages)
    return {"messages": response}

# %% [markdown]
# This node generates a summary and removes older messages.

# %%
def summarize_conversation(state: State):
    summary = state.get("summary", "")
    if summary:
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
    else:
        summary_message = "Create a summary of the conversation above:"

    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)

    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# %% [markdown]
# This function determines whether to summarize based on the number of messages.

# %%
from langgraph.graph import END
from typing_extensions import Literal

def should_continue(state: State) -> Literal ["summarize_conversation",END]:
    messages = state["messages"]
    if len(messages) > 4: # Summarize if more than 4 messages (changed from 6)
        return "summarize_conversation"
    return END

# %% [markdown]
# We'll use `MemorySaver` for persistence.

# %%
from IPython.display import Image, display
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START

workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node("summarize_conversation", summarize_conversation) # Corrected node name

workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END) # Summarize node leads to END

memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    # This is a workaround for a known issue with mermaid drawing on some systems
    print(f"Could not draw mermaid diagram: {e}")
    print("Workflow nodes:", workflow.nodes)
    print("Workflow edges:", workflow.edges)

# %% [markdown]
# Let's have a conversation to demonstrate the summarization and memory. We'll use a new thread ID.

# %%
# Create a new thread
config = {"configurable": {"thread_id": "my_custom_thread"}}

# Sample conversation
messages = [
    HumanMessage(content="What are the key differences between supervised and unsupervised learning?"),
    HumanMessage(content="Can you give me examples of each?"),
    HumanMessage(content="How is reinforcement learning different from these two?"),
    HumanMessage(content="What are some common applications of each type of machine learning?"),
]

# Invoke the graph with the messages
for i, msg in enumerate(messages):
    print(f"\n--- User Message {i+1} ---")
    print(msg.content)
    output = graph.invoke({"messages": [msg]}, config)
    print(f"\n--- AI Response {i+1} ---")
    for m in output['messages'][-1:]:
        m.pretty_print()

    # Check for summary after each turn
    current_summary = graph.get_state(config).values.get("summary","")
    print(f"\nCurrent Summary: {current_summary}")
# Out:
# --- User Message 1 ---
# What are the key differences between supervised and unsupervised learning?
#
# --- AI Response 1 ---
# ================================== Ai Message ==================================
#
# Supervised and unsupervised learning are two fundamental types of machine learning approaches. The key differences between them are:
#
# **1. Presence of Labels:**
# 	* Supervised Learning: The training data is labeled, meaning that each example is accompanied by a target output or response variable. The goal is to learn a mapping between input data and the corresponding labels.
# 	* Unsupervised Learning: The training data is unlabeled, and the algorithm must find patterns, relationships, or structure in the data without any prior knowledge of the expected output.
#
# **2. Learning Objective:**
# 	* Supervised Learning: The objective is to predict the output or response variable for new, unseen input data, based on the learned relationship between inputs and labels.
# 	* Unsupervised Learning: The objective is to discover hidden patterns, relationships, or groupings in the data, such as clustering, dimensionality reduction, or anomaly detection.
#
# **3. Algorithmic Approach:**
# 	* Supervised Learning: Algorithms are designed to minimize the error between predicted outputs and actual labels, using techniques such as regression, classification, or logistic regression.
# 	* Unsupervised Learning: Algorithms are designed to identify patterns or structure in the data, using techniques such as clustering (e.g., k-means, hierarchical clustering), dimensionality reduction (e.g., PCA, t-SNE), or density estimation.
#
# **4. Evaluation Metrics:**
# 	* Supervised Learning: Performance is typically evaluated using metrics such as accuracy, precision, recall, F1-score, mean squared error, or R-squared.
# 	* Unsupervised Learning: Evaluation metrics are often more subjective and depend on the specific problem, such as silhouette score, Calinski-Harabasz index, or visual inspection of the results.
#
# **5. Real-World Applications:**
# 	* Supervised Learning: Image classification, speech recognition, sentiment analysis, recommender systems, and predictive modeling.
# 	* Unsupervised Learning: Customer segmentation, anomaly detection, gene expression analysis, image compression, and topic modeling.
#
# In summary, supervised learning focuses on predicting outputs based on labeled data, while unsupervised learning aims to discover patterns and relationships in unlabeled data. The choice of approach depends on the problem you're trying to solve and the nature of the data you're working with.
#
# Current Summary:
#
# --- User Message 2 ---
# Can you give me examples of each?
#
# --- AI Response 2 ---
# ================================== Ai Message ==================================
#
# Here are some examples of supervised and unsupervised learning:
#
# **Supervised Learning Examples:**
#
# 1. **Image Classification**: You have a dataset of images, each labeled as either "dog" or "cat". You train a supervised learning model to predict the label for new, unseen images.
# 2. **Sentiment Analysis**: You have a dataset of text reviews, each labeled as either "positive" or "negative". You train a supervised learning model to predict the sentiment of new, unseen reviews.
# 3. **Predicting House Prices**: You have a dataset of houses, each with features like number of bedrooms, square footage, and location, along with their corresponding prices. You train a supervised learning model to predict the price of a new, unseen house based on its features.
# 4. **Speech Recognition**: You have a dataset of audio recordings, each labeled with the corresponding text transcription. You train a supervised learning model to predict the text transcription for new, unseen audio recordings.
# 5. **Medical Diagnosis**: You have a dataset of patient records, each labeled with a diagnosis (e.g. "diabetes" or "not diabetes"). You train a supervised learning model to predict the diagnosis for new, unseen patient records.
#
# **Unsupervised Learning Examples:**
#
# 1. **Customer Segmentation**: You have a dataset of customer information, including demographics, purchase history, and behavior. You use unsupervised learning to group similar customers together, identifying distinct segments or clusters.
# 2. **Anomaly Detection**: You have a dataset of network traffic, and you use unsupervised learning to identify unusual patterns or outliers that may indicate a security threat.
# 3. **Gene Expression Analysis**: You have a dataset of gene expression levels for different cells, and you use unsupervised learning to identify clusters or patterns that may indicate specific cell types or diseases.
# 4. **Image Compression**: You have a dataset of images, and you use unsupervised learning to reduce the dimensionality of the data, compressing the images while preserving their essential features.
# 5. **Topic Modeling**: You have a dataset of text documents, and you use unsupervised learning to identify underlying topics or themes that are present in the documents, without any prior knowledge of the topics.
#
# Some real-world applications that use a combination of both supervised and unsupervised learning include:
#
# * **Recommender Systems**: Use supervised learning to predict user ratings, and unsupervised learning to identify clusters of similar users or items.
# * **Fraud Detection**: Use supervised learning to predict the likelihood of fraud, and unsupervised learning to identify unusual patterns or anomalies that may indicate fraud.
# * **Natural Language Processing**: Use supervised learning to predict text classification or sentiment analysis, and unsupervised learning to identify topics or clusters in text data.
#
# These are just a few examples, but there are many more applications of supervised and unsupervised learning in various fields.
#
# Current Summary:
#
# --- User Message 3 ---
# How is reinforcement learning different from these two?
#
# --- AI Response 3 ---
# ================================== Ai Message ==================================
#
# Reinforcement learning (RL) is a type of machine learning that is distinct from supervised and unsupervised learning. The key differences are:
#
# **1. Learning Objective:**
# 	* Supervised Learning: Predict outputs based on labeled inputs.
# 	* Unsupervised Learning: Discover patterns or structure in unlabeled data.
# 	* Reinforcement Learning: Learn to take actions to maximize a reward or achieve a goal in an environment.
#
# **2. Interaction with Environment:**
# 	* Supervised Learning: The model learns from a fixed dataset, without interacting with the environment.
# 	* Unsupervised Learning: The model learns from a fixed dataset, without interacting with the environment.
# 	* Reinforcement Learning: The model interacts with the environment, taking actions and receiving feedback in the form of rewards or penalties.
#
# **3. Feedback Mechanism:**
# 	* Supervised Learning: The model receives explicit feedback in the form of labeled outputs.
# 	* Unsupervised Learning: The model does not receive explicit feedback.
# 	* Reinforcement Learning: The model receives implicit feedback in the form of rewards or penalties, which guide the learning process.
#
# **4. Exploration-Exploitation Trade-off:**
# 	* Supervised Learning: The model does not need to balance exploration and exploitation, as the optimal solution is already provided.
# 	* Unsupervised Learning: The model does not need to balance exploration and exploitation, as the goal is to discover patterns or structure.
# 	* Reinforcement Learning: The model must balance exploration (trying new actions to learn about the environment) and exploitation (choosing actions that maximize rewards based on current knowledge).
#
# **5. Agent-Environment Interaction:**
# 	* Supervised Learning: The model is a passive learner, receiving data from the environment.
# 	* Unsupervised Learning: The model is a passive learner, receiving data from the environment.
# 	* Reinforcement Learning: The model is an active learner, interacting with the environment through actions and receiving feedback.
#
# Reinforcement learning is often used in situations where:
#
# * The environment is complex and dynamic.
# * The model needs to learn to make decisions in real-time.
# * The model needs to balance exploration and exploitation to achieve a goal.
#
# Examples of reinforcement learning include:
#
# * **Game Playing**: Training an agent to play games like chess, Go, or video games.
# * **Robotics**: Training a robot to perform tasks like navigation, manipulation, or control.
# * **Autonomous Vehicles**: Training a vehicle to navigate and make decisions in a dynamic environment.
# * **Recommendation Systems**: Training a system to recommend items based on user behavior and preferences.
#
# Some key concepts in reinforcement learning include:
#
# * **Agent**: The model that interacts with the environment.
# * **Environment**: The external world that the agent interacts with.
# * **Actions**: The decisions made by the agent.
# * **Rewards**: The feedback received by the agent for its actions.
# * **Policy**: The strategy used by the agent to select actions.
# * **Value Function**: The expected return or reward for a given state or action.
#
# Reinforcement learning has many applications, and its unique characteristics make it a powerful tool for solving complex problems in a wide range of fields.
#
# Current Summary: Here's a summary of our conversation:
#
# * We discussed the key differences between **supervised learning** and **unsupervised learning**, including the presence of labels, learning objectives, algorithmic approaches, evaluation metrics, and real-world applications.
# * I provided examples of supervised learning (e.g., image classification, sentiment analysis, predicting house prices) and unsupervised learning (e.g., customer segmentation, anomaly detection, gene expression analysis).
# * We then discussed **reinforcement learning**, which is a type of machine learning that involves interacting with an environment, taking actions, and receiving feedback in the form of rewards or penalties.
# * I highlighted the key differences between reinforcement learning and supervised/unsupervised learning, including the learning objective, interaction with the environment, feedback mechanism, and exploration-exploitation trade-off.
# * I also provided examples of reinforcement learning applications, such as game playing, robotics, autonomous vehicles, and recommendation systems.
#
# Overall, our conversation covered the basics of supervised, unsupervised, and reinforcement learning, and how they differ in terms of their objectives, approaches, and applications.
#
# --- User Message 4 ---
# What are some common applications of each type of machine learning?
#
# --- AI Response 4 ---
# ================================== Ai Message ==================================
#
# Here are some common applications of each type of machine learning:
#
# **Supervised Learning:**
#
# 1. **Image Classification**: Google Photos, Facebook's image recognition, self-driving cars
# 2. **Sentiment Analysis**: Social media monitoring, customer feedback analysis, opinion mining
# 3. **Predicting House Prices**: Real estate valuation, property pricing, mortgage lending
# 4. **Speech Recognition**: Virtual assistants (e.g., Siri, Alexa), voice-controlled devices
# 5. **Medical Diagnosis**: Disease diagnosis, medical imaging analysis, patient outcome prediction
# 6. **Credit Risk Assessment**: Credit scoring, loan approval, credit card fraud detection
# 7. **Recommendation Systems**: Product recommendations (e.g., Amazon, Netflix), personalized advertising
# 8. **Natural Language Processing**: Language translation, text summarization, chatbots
#
# **Unsupervised Learning:**
#
# 1. **Customer Segmentation**: Market research, customer profiling, targeted marketing
# 2. **Anomaly Detection**: Fraud detection, network security, quality control
# 3. **Gene Expression Analysis**: Genomics, proteomics, personalized medicine
# 4. **Clustering**: Customer segmentation, market basket analysis, gene expression analysis
# 5. **Dimensionality Reduction**: Data visualization, feature extraction, data compression
# 6. **Topic Modeling**: Text analysis, document clustering, information retrieval
# 7. **Network Analysis**: Social network analysis, community detection, link prediction
# 8. **Recommendation Systems**: Content-based filtering, collaborative filtering, hybrid approaches
#
# **Reinforcement Learning:**
#
# 1. **Game Playing**: AlphaGo, AlphaZero, game playing AI
# 2. **Robotics**: Robot control, navigation, manipulation, and learning
# 3. **Autonomous Vehicles**: Self-driving cars, autonomous drones, and other vehicles
# 4. **Recommendation Systems**: Personalized recommendations, adaptive systems
# 5. **Financial Trading**: Algorithmic trading, portfolio optimization, risk management
# 6. **Smart Grids**: Energy management, demand response, and optimization
# 7. **Healthcare**: Personalized medicine, treatment planning, and patient engagement
# 8. **Cybersecurity**: Intrusion detection, incident response, and security analytics
#
# These are just a few examples of the many applications of each type of machine learning. The boundaries between these categories can be blurry, and many applications may involve a combination of multiple machine learning approaches.
#
# Some key trends and areas of research in machine learning include:
#
# * **Deep Learning**: Neural networks, convolutional neural networks, recurrent neural networks
# * **Transfer Learning**: Using pre-trained models for new tasks and domains
# * **Explainability**: Interpreting and understanding machine learning models and decisions
# * **Adversarial Robustness**: Defending against adversarial attacks and improving model robustness
# * **Multi-Agent Systems**: Cooperative and competitive learning in multi-agent environments
#
# As machine learning continues to evolve, we can expect to see new applications, techniques, and innovations emerge in various fields and industries.
#
# Current Summary: Here's a summary of our conversation:
#
# * We discussed the key differences between **supervised learning** and **unsupervised learning**, including the presence of labels, learning objectives, algorithmic approaches, evaluation metrics, and real-world applications.
# * I provided examples of supervised learning (e.g., image classification, sentiment analysis, predicting house prices) and unsupervised learning (e.g., customer segmentation, anomaly detection, gene expression analysis).
# * We then discussed **reinforcement learning**, which is a type of machine learning that involves interacting with an environment, taking actions, and receiving feedback in the form of rewards or penalties.
# * I highlighted the key differences between reinforcement learning and supervised/unsupervised learning, including the learning objective, interaction with the environment, feedback mechanism, and exploration-exploitation trade-off.
# * I also provided examples of reinforcement learning applications, such as game playing, robotics, autonomous vehicles, and recommendation systems.
#
# Overall, our conversation covered the basics of supervised, unsupervised, and reinforcement learning, and how they differ in terms of their objectives, approaches, and applications.

# %% [markdown]
# Here is the final summary of the last prompt observed on Langsmith traces:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
